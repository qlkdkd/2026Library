# %%
print(f'aaa {None}')
# Out:
# aaa None

# %%
from datetime import datetime

today = datetime.today()
print(today)
print(type(today))
# Out:
# 2026-06-29 10:09:29.319726
# <class 'datetime.datetime'>

# %%
print(str(today))
print(str(today).split())
today = str(today).split()
print(today[0])
# Out:
# 2026-06-29 10:09:29.319726
# ['2026-06-29', '10:09:29.319726']
# 2026-06-29

# %%
print(today[0][:7]+'-01')
# Out:
# 2026-06-01
