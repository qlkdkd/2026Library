# %%
import osmnx as ox
import networkx as nx
import pandas as pd

# 1. 의정부 지역의 도보 도로망 데이터 가져오기
G = ox.graph_from_place('Uijeongbu, South Korea', network_type='walk')
libDf = pd.read_csv('./resource/library_list.csv')

# %%
lib_cond = libDf['도서관명'] == '의정부미술도서관'
libDf = libDf[lib_cond]

# %%
print(float(libDf['위도']), float(libDf['경도']))
# Out:
# 37.7533135 127.1073975
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_99128\3482674098.py:1: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print(float(libDf['위도']), float(libDf['경도']))
