# %%
import requests
import pandas as pd

# %%
df = pd.read_csv('result_남성_20대_의정부시.csv')
df.head()
# Out:
#    no  ranking          bookname   authors publisher  publication_year  \
# 0   1        1  안녕이라 그랬어 :김애란 소설  지은이: 김애란      문학동네            2025.0
# 1   2        2   소년이 온다 :한강 장편소설   지은이: 한강        창비            2014.0
# 2   3        3      혼모노 :성해나 소설집  지은이: 성해나        창비            2025.0
# 3   4        4      모순 :양귀자 장편소설  지은이: 양귀자        쓰다            2013.0
# 4   5        5      절창 :구병모 장편소설  지은이: 구병모      문학동네            2025.0
#
#           isbn13  addition_symbol  vol  class_no        class_nm  \
# 0  9791141602376           3810.0  NaN    813.70  문학 > 한국문학 > 소설
# 1  9788936434120           3810.0  NaN    813.62  문학 > 한국문학 > 소설
# 2  9788936439743           3810.0  NaN    813.70  문학 > 한국문학 > 소설
# 3  9788998441012           3810.0  NaN    813.62  문학 > 한국문학 > 소설
# 4  9791141602451           3810.0  NaN    813.70  문학 > 한국문학 > 소설
#
#                                         bookImageURL  \
# 0  https://image.aladin.co.kr/product/36566/52/co...
# ...

# %%
urls = df['bookDtlUrl']
urls
# Out:
# 0        https://data4library.kr/bookV?seq=7073819
# 1        https://data4library.kr/bookV?seq=2037399
# 2        https://data4library.kr/bookV?seq=7035395
# 3        https://data4library.kr/bookV?seq=1938053
# 4        https://data4library.kr/bookV?seq=7149374
#                            ...
# 1995     https://data4library.kr/bookV?seq=6352258
# 1996     https://data4library.kr/bookV?seq=6666830
# 1997     https://data4library.kr/bookV?seq=6928588
# 1998     https://data4library.kr/bookV?seq=7256779
# 1999     https://data4library.kr/bookV?seq=7140748
# Name: bookDtlUrl, Length: 2000, dtype: str

# %%
# requests 패키지 가져오기
import requests    
from bs4 import BeautifulSoup as bs           

# 가져올 url 문자열로 입력
url = 'https://data4library.kr/bookV?seq=5799196'  

# requests의 get함수를 이용해 해당 url로 부터 html이 담긴 자료를 받아옴
response = requests.get(url)

# 우리가 얻고자 하는 html 문서가 여기에 담기게 됨
html_text = response.text
html = bs(html_text, 'html.parser')
html
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=yes" name="viewport"/>
# <meta content="국립중앙도서관에서 운영하는 도서관 정보나루입니다." name="description"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!-- 현재페이지 제목 - 첫번째 하위메뉴 - 메인메뉴 -->
# <title>
#
#
#
#
#
#
#
#
# 						도서 상세조회 - 도서별 이용분석 -
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		도서관 정보나루
# 	</title>
# <!-- CSS 파일 -->
# <link href="/resources/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="/resources/css/bootstrap-icons.css" rel="stylesheet"/>
# <link href="/resources/css/jquery/jquery-ui.css" rel="stylesheet"/>
# <link href="/resources/css/layout.css" rel="stylesheet"/>
# <link href="/resources/css/mquery.css" rel="stylesheet"/>
# <link href="/resources/css/custom.css" rel="stylesheet"/>
# <!-- SweetAlert2 CSS -->
# ...

# %%
html_str = str(html)
html_str
# Out:
# '\n<!DOCTYPE html>\n\n<html lang="ko">\n<head>\n<meta content="text/html; charset=utf-8" http-equiv="content-type"/>\n<meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=yes" name="viewport"/>\n<meta content="국립중앙도서관에서 운영하는 도서관 정보나루입니다." name="description"/>\n<meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n<!-- 현재페이지 제목 - 첫번째 하위메뉴 - 메인메뉴 -->\n<title>\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t도서 상세조회 - 도서별 이용분석 -\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\n\t\t도서관 정보나루\n\t</title>\n<!-- CSS 파일 -->\n<link href="/resources/css/bootstrap.min.css" rel="stylesheet"/>\n<link href="/resources/css/bootstrap-icons.css" rel="stylesheet"/>\n<link href="/resources/css/jquery/jquery-ui.css" rel="stylesheet"/>\n<link href="/r
# ...

# %%
file_path = './datas/bookinfo.txt'

with open(file_path, 'w', encoding='utf-8') as file:
    file.write(html_str)

# %%
url = 'https://data4library.kr/bookV?seq=7073819'
response = requests.get(url)
html_text = response.text
html = bs(html_text, 'html.parser')
html_str = str(html)


file_path = './datas/bookinfo_.html'
with open(file_path, 'w', encoding='utf-8') as file:
    file.write(html_str)

# %%
type(html)
# Out:
# bs4.BeautifulSoup

# %%
#bookinfo.html에서 1016번 라인의 <p>태그
txt_data = html.find(class_="v_b_abstract")
print(txt_data)
print(type(txt_data))
# Out:
# <div class="v_b_abstract">
# <h4>책소개</h4>
# <p>소설가 김애란이 『바깥은 여름』 이후 팔 년 만에 새 소설집으로 돌아왔다. 2022 김승옥문학상 우수상을 수상한 「홈 파티」와 2022 오영수문학상 수상작인 「좋은 이웃」을 비롯해 총 일곱 편의 단편이 수록되어 있다.</p>
# </div>
# <class 'bs4.element.Tag'>

# %%
clean_text = txt_data.get_text()
clean_text
# Out:
# '\n책소개\n소설가 김애란이 『바깥은 여름』 이후 팔 년 만에 새 소설집으로 돌아왔다. 2022 김승옥문학상 우수상을 수상한 「홈 파티」와 2022 오영수문학상 수상작인 「좋은 이웃」을 비롯해 총 일곱 편의 단편이 수록되어 있다.\n'

# %%
clean_text = clean_text.replace('\n책소개\n', '')
clean_text = clean_text.replace('\n', '')
clean_text
# Out:
# '소설가 김애란이 『바깥은 여름』 이후 팔 년 만에 새 소설집으로 돌아왔다. 2022 김승옥문학상 우수상을 수상한 「홈 파티」와 2022 오영수문학상 수상작인 「좋은 이웃」을 비롯해 총 일곱 편의 단편이 수록되어 있다.'
